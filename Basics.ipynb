# %%
import pandas as pd
data = pd.read_csv("thanksgiving.csv",encoding='Latin-1')
data.head()
# Out:
#    RespondentID Do you celebrate Thanksgiving?  \
# 0    4337954960                            Yes
# 1    4337951949                            Yes
# 2    4337935621                            Yes
# 3    4337933040                            Yes
# 4    4337931983                            Yes
#
#   What is typically the main dish at your Thanksgiving dinner?  \
# 0                                             Turkey
# 1                                             Turkey
# 2                                             Turkey
# 3                                             Turkey
# 4                                           Tofurkey
#
#   What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
print(data.columns)
# Out:
# Index(['RespondentID', 'Do you celebrate Thanksgiving?',
#        'What is typically the main dish at your Thanksgiving dinner?',
#        'What is typically the main dish at your Thanksgiving dinner? - Other (please specify)',
#        'How is the main dish typically cooked?',
#        'How is the main dish typically cooked? - Other (please specify)',
#        'What kind of stuffing/dressing do you typically have?',
#        'What kind of stuffing/dressing do you typically have? - Other (please specify)',
#        'What type of cranberry saucedo you typically have?',
#        'What type of cranberry saucedo you typically have? - Other (please specify)',
#        'Do you typically have gravy?',
#        'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Brussel sprouts',
#        'Which of these side dishes aretypically served at your Thanksgiving dinner? Please select all that apply. - Carrots',
# ...

# %%
#Filter out any of those surveyed who do not celebrate Thanksgiving
data = data[data['Do you celebrate Thanksgiving?'] == 'Yes']
data.head(20)
# Out:
#     RespondentID Do you celebrate Thanksgiving?  \
# 0     4337954960                            Yes
# 1     4337951949                            Yes
# 2     4337935621                            Yes
# 3     4337933040                            Yes
# 4     4337931983                            Yes
# 5     4337929779                            Yes
# 6     4337924420                            Yes
# 7     4337916002                            Yes
# 8     4337914977                            Yes
# 9     4337899817                            Yes
# 11    4337893416                            Yes
# 12    4337888291                            Yes
# 13    4337878450                            Yes
# 14    4337878351                            Yes
# 15    4337857295                            Yes
# 16    4337856362                            Yes
# 17    4337854106                            Yes
# 18    4337844879                            Yes
# ...

# %%
#Display counts of how many times each category occurs in:
# "What is typically the main dish at your Thanksgiving dinner?"

main_dish_counts = data['What is typically the main dish at your Thanksgiving dinner?'].value_counts()

#Filter the columns where tofurkey is typically the main dish served
# at their Thanksgiving
tofurkey_filter = data[data['What is typically the main dish at your Thanksgiving dinner?'] == 'Tofurkey']

#Display the "Do you typically have gracy" column for the participants
# who have tofurkey as their main dish for Thanksgiving
tofurkey_filter['Do you typically have gravy?']
# Out:
# 4      Yes
# 33     Yes
# 69      No
# 72      No
# 77     Yes
# 145    Yes
# 175    Yes
# 218     No
# 243    Yes
# 275     No
# 393    Yes
# 399    Yes
# 571    Yes
# 594    Yes
# 628     No
# 774     No
# 820     No
# 837    Yes
# 860     No
# 953    Yes
# Name: Do you typically have gravy?, dtype: object

# %%
#In order to find out the count of how many people eat either of the
# three pies for thanksgiving, we make boolean series to see where
# the entries are null.
apple_isnull = data['Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Apple'].isnull()
pumpkin_isnull = data['Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pumpkin'].isnull()
pecan_isnull = data['Which type of pie is typically served at your Thanksgiving dinner? Please select all that apply. - Pecan'].isnull()

#We then combine all of these boolean series into one, where the result is
# false, at least one type of pie was eaten, if true, none of the types
# of pies were eaten.
ate_pies = apple_isnull & pumpkin_isnull & pecan_isnull

print(ate_pies.unique)
# Out:
# <bound method Series.unique of 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5        True
# 6       False
# 7        True
# 8       False
# 9       False
# 11      False
# 12      False
# 13      False
# 14      False
# 15       True
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21       True
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
# 30      False
# 32      False
#         ...
# 1024    False
# 1025    False
# 1026    False
# 1027    False
# 1029    False
# 1030    False
# 1031    False
# 1033    False
# 1034    False
# 1035    False
# 1037     True
# 1038    False
# 1039    False
# 1040    False
# 1041    False
# 1042    False
# 1043     True
# 1044    False
# 1045    False
# 1046    False
# 1047    False
# 1048    False
# 1049    False
# 1050    False
# 1051    False
# 1053    False
# 1054    False
# 1055    False
# 1056     True
# ...

# %%
#We create a function to split each string, if it isn't null by the spaces
# we next take the plus sign off of the 60+ entires, we convert this
# stripped down string into an integer
def convert_age(string):
    if pd.isnull(string):
        return None
    else:
        c1 = string.split(" ")[0]
        c1 = c1.replace("+"," ")
        return int(c1)
        
#We take the function we created and apply it to the Age column to
# loosely estimte the ages of each participant
data['int_age'] = data['Age'].apply(convert_age)
data['int_age'].describe()
# Out:
# count    947.000000
# mean      40.089757
# std       15.352014
# min       18.000000
# 25%       30.000000
# 50%       45.000000
# 75%       60.000000
# max       60.000000
# Name: int_age, dtype: float64

# %%
#We re work the fucntion in the previous cell to fit our needs to extract
# income data from the column that asks for the combined amount of
# money earned in each participant's hosuehold
def convert_income(string):
    if pd.isnull(string):
        return None
    c1 = string.split(" ")[0]
    if c1 == "Prefer":
        return None
    else:
        c1 = c1.replace('$','')
        c1 = c1.replace(',','')
        return int(c1)
            
data['int_income'] = data['How much total combined money did all members of your HOUSEHOLD earn last year?'].apply(convert_income)          
data['int_income'].describe()
# Out:
# count       829.000000
# mean      75965.018094
# std       59068.636748
# min           0.000000
# 25%       25000.000000
# 50%       75000.000000
# 75%      100000.000000
# max      200000.000000
# Name: int_income, dtype: float64

# %% [markdown]
# # Progress thus far
# - So far we have read in the data, looked at the columns, and filtered the data to the participants who actually celebrated Thanksgiving.
# - We examined the participants who ate tofurkey as their main dish and whether they had gravy with it or not.
# - We also examined the participants who had either apple, pumpkin, or peacan pie or none of the three for dessert
# - We then finished out with a very loose approximation of age and total household income for each participant based on their answers for age and total household income
# - As for the incomes of participants that we estimated, we would definitely need a more detailed answers rather than a range they fall into. Assuming this survey is randomized, I have a hard time believing that the average total income across all participants is almost $760000

# %%
data_150000_under = data[data["int_income"]<150000]
travel_counts_under_150000 = data_150000_less["How far will you travel for Thanksgiving?"].value_counts()

data_150000_over = data[data["int_income"]>150000]
travel_counts_over_150000 = data_150000_over["How far will you travel for Thanksgiving?"].value_counts()

print(travel_counts_under_150000)
print('---------------------------------------------')
print(travel_counts_over_150000)
# Out:
# Thanksgiving is happening at my home--I won't travel at all                         281
# Thanksgiving is local--it will take place in the town I live in                     203
# Thanksgiving is out of town but not too far--it's a drive of a few hours or less    150
# Thanksgiving is out of town and far away--I have to drive several hours or fly       55
# Name: How far will you travel for Thanksgiving?, dtype: int64
# ---------------------------------------------
# Thanksgiving is happening at my home--I won't travel at all                         49
# Thanksgiving is local--it will take place in the town I live in                     25
# Thanksgiving is out of town but not too far--it's a drive of a few hours or less    16
# Thanksgiving is out of town and far away--I have to drive several hours or fly      12
# Name: How far will you travel for Thanksgiving?, dtype: int64

# %% [markdown]
# # Findings
# - Based on these results it seems as if households earning lower than 150,000 total income are staying home and less are flying out
# - However the same seems to be true with households earning over 150,000, I think this is because there isn't a big enough sample of both categories to make a reasonable enough assumption or see the difference we would expect

# %%
pivot_table_friendsgiving_age = data.pivot_table(index="Have you ever tried to meet up with hometown friends on Thanksgiving night?",columns = 'Have you ever attended a "Friendsgiving?"', values = "int_age")

pivot_table_friendsgiving_inc = data.pivot_table(index="Have you ever tried to meet up with hometown friends on Thanksgiving night?",columns='Have you ever attended a "Friendsgiving?"',values="int_income")


pivot_table_friendsgiving_age
pivot_table_friendsgiving_inc
# Out:
# Have you ever attended a "Friendsgiving?"                     No           Yes
# Have you ever tried to meet up with hometown fr...
# No                                                  78914.549654  72894.736842
# Yes                                                 78750.000000  66019.736842

# %% [markdown]
# # Findings
# - It seems as if younger participants and participants with lower total household income on average celebrate Friendsgiving more then their older higher total income earning counterparts
